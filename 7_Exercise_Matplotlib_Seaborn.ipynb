# %% [markdown]
# This telco-customer-churn dataset contains 7044 rows and 21 coloumns. Churn analysis is basically done to know the reason that why a particular company is loosing its customer. so that the company can reduce that rate. Churn analysis helps you identify pain points throughout the entire customer journey

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv('7_WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %% [markdown]
# **Q-1** Mention the first five entries of the above mentioned data set.

# %%
## Write your code here
df.head(5)
#df.columns
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# **Q-2** Using seaborn library, plot the graph between churn and count of churn.

# %%
## Write your code here
ax = df.Churn.value_counts().plot(kind='bar',title='Churn Type against Count of Churn')
ax.set_xlabel("Churn Type")
ax.set_ylabel("Count of Churn")
# Out:
# Text(0, 0.5, 'Count of Churn')

# %% [markdown]
# **Q-3** Plot the scatter graph to show the relationship between tenure & Monthly charges

# %%
## Write your code here
plt.scatter(df['tenure'], df['MonthlyCharges'])
plt.xlabel('Tenure')
plt.ylabel('Monthly Charges')
plt.title("Relationship between Tenure & Monthly Charges")
plt.show()

# %% [markdown]
# **Q-4** Write the total number of rows and coloumn in the given data set.

# %%
## Write your code here
[row,column]=df.shape
print('there are',row,'rows and',column,'columns in the dataframe')
# Out:
# there are 7043 rows and 21 columns in the dataframe

# %% [markdown]
# **Q-5** Write the code for getting the summary statistics of the numerical columns?

# %%
## Write your code here
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# **Q-6** Plot the bargraph between Count of target variable per category.

# %%
## Write your code here
ax = sns.countplot(data=df, x='Churn', order=df.Churn.value_counts().index)
#add exact values on top of the bar chart
for i in ax.containers:
    ax.bar_label(i,)
ax.set_xlabel("Churn Type")
ax.set_ylabel("Count of Churn")
ax.set_title("Count of Churn per Category")
# Out:
# Text(0.5, 1.0, 'Count of Churn per Category')

# %% [markdown]
# **Q-7** Plot the graph between monthly charges and total charges.

# %%
## Write your code here
df.plot(y = 'MonthlyCharges', x = 'TotalCharges', kind = 'bar')
plt.xlabel('Total Charges')
plt.ylabel('Monthly Charges')
plt.title("Total Charges against Monthly Charges")
plt.show()

# %% [markdown]
# **Q-8** check the distribution of the target varible (i.e churn )

# %%
## Write your code here
#sns.pairplot(df)
#df['Churn'].hist()
ax = sns.histplot(df['Churn'])
for i in ax.containers:
    ax.bar_label(i,)
ax.set_xlabel("Churn Type")
ax.set_ylabel("Count of Churn")
ax.set_title("Distribution of the Churn")
# Out:
# Text(0.5, 1.0, 'Distribution of the Churn')

# %% [markdown]
# **Q-9** Plot the scatter graph between total charges and monthly charges.

# %%
## Write your code here
df.plot(y = 'MonthlyCharges', x = 'TotalCharges', kind = 'scatter')
plt.xlabel('Total Charges')
plt.ylabel('Monthly Charges')
plt.title("Total Charges against Monthly Charges")
plt.show()

# %% [markdown]
# **Q-10** Plot the join plot between total charges and monthly charges. (Use seaborn.jointplot)

# %%
## Write your code here
j = sns.jointplot(data=df, y="MonthlyCharges", x="TotalCharges")

# set labels via the axes objects
j.ax_joint.set_xlabel('Total Charges')
j.ax_joint.set_ylabel('Monthly Charges')
# also possible to manipulate the histogram plots this way, e.g.
j.ax_marg_y.grid('on') # with ugly consequences...

# labels appear outside of plot area, so auto-adjust
j.figure.tight_layout()

# %% [markdown]
# **Q-11** Total Charges should be numeric amount. Let's convert it to numerical data type and check whether it has any null values or not.

# %%
## Write your code here
#try to change column TotalCharges to numeric, had error due to missing value, 
#so errors = 'coerce' will change those values to NaN
df['TotalCharges']=pd.to_numeric(df['TotalCharges'],errors = 'coerce')

# %% [markdown]
# **Q-12** As we can see there are 11 missing values in TotalCharges column. Let's check these records

# %%
## Write your code here
df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# **Q-13** Convert the target variable 'Churn' in a binary numeric variable i.e. Yes=1 ; No = 0

# %%
## Write your code here
# convert into number. Since there are two values, it will be binary values
df['Churn'] = (df['Churn'] == 'Yes').astype(int)
df['Churn']
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7043, dtype: int32

# %% [markdown]
# **Q-14** Build a corelation of all predictors with 'Churn' and plot a bar chart (Use dataframe.corr() function)

# %%
## Write your code here
#use pearson correlation
corr=df.corr(method ='pearson')
#take all correlation coeffecient of the predictors only
corr_bar=corr['Churn'].head(3)
#plot bar chart
ax =corr_bar.plot.bar()
#display value on top og the bar
ax.bar_label(ax.containers[0], fmt='{:,.3f}')
ax.set_xlabel("Churn Type")
ax.set_ylabel("Correlation Coeffecient with Churn")
ax.set_title("Distribution of the Churn")
# Out:
# C:\Users\oggy0\AppData\Local\Temp\ipykernel_17780\2410957488.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr(method ='pearson')
# Text(0.5, 1.0, 'Distribution of the Churn')

# %% [markdown]
# **Q-15** Plot a pie chart showing the distribution of the Payment Methods

# %%
## Write your code here
df['PaymentMethod'].value_counts().plot(kind='pie',autopct='%1.0f%%')
plt.title("Distribution of the Payment Methods")
plt.axis('off')
plt.show()
#payment_method

# %% [markdown]
# **Q-16** Plot a line chart showing the distribution of tenure

# %%
## Write your code here
df['tenure'].value_counts().sort_index().plot(kind='line')
plt.title("Distribution of tenure (Line Graph)")
plt.xlabel('Tenure')
plt.ylabel('Count of Tenure')
plt.show()

# %% [markdown]
# **Q-17** Plot an area chart showing the distribution of tenure

# %%
## Write your code here
df['tenure'].value_counts().sort_index().plot(kind='area')
plt.title("Distribution of tenure (Area Graph)")
plt.xlabel('Tenure')
plt.ylabel('Count of Tenure')
plt.show()
